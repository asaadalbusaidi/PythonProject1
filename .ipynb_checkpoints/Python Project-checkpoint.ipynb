# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
plt.style.use('ggplot')
df=pd.read_csv('HR-Employee-Attrition.csv')

# %%
df.shape
# Out:
# (906, 36)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# rows * columns
df.size
# Out:
# 32616

# %%
df.head()
# Out:
#    Unnamed: 0  Age Attrition     BusinessTravel  DailyRate  \
# 0           1   49        No  Travel_Frequently        279
# 1           2   37       Yes      Travel_Rarely       1373
# 2           3   33        No  Travel_Frequently       1392
# 3           5   32        No  Travel_Frequently       1005
# 4           7   30        No      Travel_Rarely       1358
#
#                Department  DistanceFromHome      Education EducationField  \
# 0  Research & Development                 8  Below College  Life Sciences
# 1  Research & Development                 2        College          Other
# 2  Research & Development                 3         Master  Life Sciences
# 3  Research & Development                 2        College  Life Sciences
# 4  Research & Development                24  Below College  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                 Very High            80
# 1              1  ...                    Medium            80
# 2              1  ...                      High            80
# 3              1  ...                      High            80
# 4              1  ...                    Medium            80
#
#   StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                1                 10                     3           Better
# 1                0                  7                     3           Better
# 2                0                  8                     3           Better
# 3                0                  8                     2             Good
# 4                1                  1                     2           Better
#
#   YearsAtCompany YearsInCurrentRole YearsSinceLastPromotion  \
# 0             10                  7                       1
# 1              0                  0                       0
# 2              8                  7                       3
# 3              7                  7                       3
# 4              1                  0                       0
#
#    YearsWithCurrManager
# 0                     7
# 1                     0
# 2                     0
# 3                     6
# 4                     0
#
# [5 rows x 36 columns]

# %%
# check the null values 
df.isnull()
# Out:
#      Unnamed: 0    Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0         False  False      False           False      False       False
# 1         False  False      False           False      False       False
# 2         False  False      False           False      False       False
# 3         False  False      False           False      False       False
# 4         False  False      False           False      False       False
# ..          ...    ...        ...             ...        ...         ...
# 901       False  False      False           False      False       False
# 902       False  False      False           False      False       False
# 903       False  False      False           False      False       False
# 904       False  False      False           False      False       False
# 905       False  False      False           False      False       False
#
#      DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0               False      False           False          False  ...
# 1               False      False           False          False  ...
# 2               False      False           False          False  ...
# 3               False      False           False          False  ...
# 4               False      False           False          False  ...
# ..                ...        ...             ...            ...  ...
# 901             False      False           False          False  ...
# 902             False      False           False          False  ...
# 903             False      False           False          False  ...
# 904             False      False           False          False  ...
# 905             False      False           False          False  ...
#
#      RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                       False          False             False
# 1                       False          False             False
# 2                       False          False             False
# 3                       False          False             False
# 4                       False          False             False
# ..                        ...            ...               ...
# 901                     False          False             False
# 902                     False          False             False
# 903                     False          False             False
# 904                     False          False             False
# 905                     False          False             False
#
#      TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                False                  False            False
# 1                False                  False            False
# 2                False                  False            False
# 3                False                  False            False
# 4                False                  False            False
# ..                 ...                    ...              ...
# 901              False                  False            False
# 902              False                  False            False
# 903              False                  False            False
# 904              False                  False            False
# 905              False                  False            False
#
#      YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0             False               False                    False
# 1             False               False                    False
# 2             False               False                    False
# 3             False               False                    False
# 4             False               False                    False
# ..              ...                 ...                      ...
# 901           False               False                    False
# 902           False               False                    False
# 903           False               False                    False
# 904           False               False                    False
# 905           False               False                    False
#
#      YearsWithCurrManager
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ..                    ...
# 901                 False
# 902                 False
# 903                 False
# 904                 False
# 905                 False
#
# [906 rows x 36 columns]

# %%
# check the null values 
np.sum(df.isnull())
# Out:
# Unnamed: 0                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# check if there is empty data
df.empty
# Out:
# False

# %%
# check for duplicate data
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 901    False
# 902    False
# 903    False
# 904    False
# 905    False
# Length: 906, dtype: bool

# %%
df.head()
# Out:
#    Unnamed: 0  Age Attrition     BusinessTravel  DailyRate  \
# 0           1   49        No  Travel_Frequently        279
# 1           2   37       Yes      Travel_Rarely       1373
# 2           3   33        No  Travel_Frequently       1392
# 3           5   32        No  Travel_Frequently       1005
# 4           7   30        No      Travel_Rarely       1358
#
#                Department  DistanceFromHome      Education EducationField  \
# 0  Research & Development                 8  Below College  Life Sciences
# 1  Research & Development                 2        College          Other
# 2  Research & Development                 3         Master  Life Sciences
# 3  Research & Development                 2        College  Life Sciences
# 4  Research & Development                24  Below College  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                 Very High            80
# 1              1  ...                    Medium            80
# 2              1  ...                      High            80
# 3              1  ...                      High            80
# 4              1  ...                    Medium            80
#
#   StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                1                 10                     3           Better
# 1                0                  7                     3           Better
# 2                0                  8                     3           Better
# 3                0                  8                     2             Good
# 4                1                  1                     2           Better
#
#   YearsAtCompany YearsInCurrentRole YearsSinceLastPromotion  \
# 0             10                  7                       1
# 1              0                  0                       0
# 2              8                  7                       3
# 3              7                  7                       3
# 4              1                  0                       0
#
#    YearsWithCurrManager
# 0                     7
# 1                     0
# 2                     0
# 3                     6
# 4                     0
#
# [5 rows x 36 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0         Age    DailyRate  DistanceFromHome  EmployeeCount  \
# count   906.000000  906.000000   906.000000        906.000000          906.0
# mean    739.299117   34.991170   798.536424          9.299117            1.0
# std     428.514074    8.274165   400.540846          8.089686            0.0
# min       1.000000   18.000000   103.000000          1.000000            1.0
# 25%     374.500000   29.000000   465.000000          2.000000            1.0
# 50%     725.500000   34.000000   794.500000          7.000000            1.0
# 75%    1112.750000   40.000000  1153.000000         14.000000            1.0
# max    1469.000000   60.000000  1498.000000         29.000000            1.0
#
#        EmployeeNumber  HourlyRate    JobLevel  MonthlyIncome   MonthlyRate  \
# count      906.000000  906.000000  906.000000     906.000000    906.000000
# mean      1031.719647   65.476821    1.662252    4650.564018  14073.952539
# std        607.788943   20.442400    0.658685    2246.007367   7038.282069
# min          2.000000   30.000000    1.000000    1051.000000   2097.000000
# 25%        498.500000   48.000000    1.000000    2731.250000   7983.000000
# 50%       1010.500000   66.000000    2.000000    4307.000000  13936.500000
# 75%       1573.750000   83.000000    2.000000    5896.000000  20111.250000
# max       2068.000000  100.000000    3.000000   10761.000000  26968.000000
#
#        NumCompaniesWorked  PercentSalaryHike  StandardHours  StockOptionLevel  \
# count          906.000000         906.000000          906.0        906.000000
# mean             2.347682          15.294702           80.0          0.663355
# std              2.192272           3.647797            0.0          0.692759
# min              0.000000          11.000000           80.0          0.000000
# 25%              1.000000          12.000000           80.0          0.000000
# 50%              1.000000          14.000000           80.0          1.000000
# 75%              4.000000          18.000000           80.0          1.000000
# max              8.000000          25.000000           80.0          2.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# count         906.000000             906.000000      906.000000
# mean            8.632450               2.532009        5.711921
# std             4.696138               0.754780        4.009355
# min             0.000000               1.000000        0.000000
# 25%             5.000000               2.000000        3.000000
# 50%             8.000000               2.000000        5.000000
# 75%            11.000000               3.000000        8.000000
# max            20.000000               4.000000       20.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count          906.000000               906.000000            906.000000
# mean             3.757174                 1.707506              3.687638
# std              3.177368                 2.466906              3.107397
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              3.000000                 1.000000              3.000000
# 75%              7.000000                 2.000000              7.000000
# max             16.000000                15.000000             14.000000

# %%
check_outlier=df[['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked','Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
      'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
ax = sns.boxplot(data=check_outlier, orient="h", palette="Set1")

# %%
check_outlier1=df[['Age', 'DailyRate','DistanceFromHome', 'HourlyRate', 'JobLevel',
                   'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked']]

check_outlier2=df[['PercentSalaryHike', 'StandardHours', 'StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsWithCurrManager']]

# %%
ax = sns.boxplot(data=check_outlier1, orient="h", palette="Set2")

# %%
ax = sns.boxplot(data=check_outlier2, orient="h", palette="Set2")

# %%
#sns.boxplot(x='Age', data=df) 
#sns.boxplot(x='DistanceFromHome', data=df)
#sns.boxplot(x='HourlyRate', data=df)
#sns.boxplot(x='JobLevel', data=df)
#sns.boxplot(x='MonthlyRate', data=df)
#sns.boxplot(x='PercentSalaryHike', data=df)
#sns.boxplot(x='StandardHours', data=df)
#==========================================
#Outliers
#sns.boxplot(x='MonthlyIncome', data=df)
#sns.boxplot(x='StockOptionLevel', data=df)
#sns.boxplot(x='TotalWorkingYears', data=df)
#sns.boxplot(x='TrainingTimesLastYear', data=df)
#sns.boxplot(x='YearsWithCurrManager', data=df)
#sns.boxplot(x='NumCompaniesWorked', data=df)
#==========================================
Outliers_Detected=df[['MonthlyIncome','StockOptionLevel', 'TotalWorkingYears', 
                    'TrainingTimesLastYear','YearsWithCurrManager','NumCompaniesWorked']]
ax = sns.boxplot(data=Outliers_Detected, orient="h", palette="Set2")

# %%
#Q1 The 1st quartile/25th percentile of the data.
#Q2 The 2nd quartile/median/50th percentile of the data.
#Q3 The 3rd quartile/75th percentile of the data.
out=[]
def iqr_outliers(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    for i in df:
        if i > Upper_tail or i < Lower_tail:
            out.append(i)
    print("Outliers:",out)
iqr_outliers(df['NumCompaniesWorked'])
iqr_outliers(df['MonthlyIncome'])
iqr_outliers(df['StockOptionLevel'])
iqr_outliers(df['TotalWorkingYears'])
iqr_outliers(df['TrainingTimesLastYear'])
iqr_outliers(df['YearsWithCurrManager'])
# Out:
# Outliers: []
# Outliers: [10650, 10725, 10761, 10686]
# Outliers: [10650, 10725, 10761, 10686]
# Outliers: [10650, 10725, 10761, 10686]
# Outliers: [10650, 10725, 10761, 10686]
# Outliers: [10650, 10725, 10761, 10686]

# %%
# Droping the ouliers using percentile
def drop_outliers(df, field_name):
    iqr = 1.5 * (np.percentile(df[field_name], 75) - np.percentile(df[field_name], 25))
    df.drop(df[df[field_name] > (iqr + np.percentile(df[field_name], 75))].index, inplace=True)
    df.drop(df[df[field_name] < (np.percentile(df[field_name], 25) - iqr)].index, inplace=True)
drop_outliers(df, 'MonthlyIncome')
drop_outliers(df, 'StockOptionLevel')
drop_outliers(df, 'TotalWorkingYears')
drop_outliers(df, 'TrainingTimesLastYear')
drop_outliers(df, 'YearsWithCurrManager')
drop_outliers(df, 'NumCompaniesWorked')

# %%
df1=df[df['MonthlyIncome']>10700]
df1
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 36 columns]

# %%
sns.boxplot(x='MonthlyIncome', data=df1)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
df['MonthlyIncome'].describe()
# Out:
# count      902.000000
# mean      4623.712860
# std       2214.374059
# min       1051.000000
# 25%       2725.750000
# 50%       4296.000000
# 75%       5812.500000
# max      10609.000000
# Name: MonthlyIncome, dtype: float64

# %%
df.shape
# Out:
# (902, 36)

# %%
df.head()
# Out:
#    Unnamed: 0  Age Attrition     BusinessTravel  DailyRate  \
# 0           1   49        No  Travel_Frequently        279
# 1           2   37       Yes      Travel_Rarely       1373
# 2           3   33        No  Travel_Frequently       1392
# 3           5   32        No  Travel_Frequently       1005
# 4           7   30        No      Travel_Rarely       1358
#
#                Department  DistanceFromHome      Education EducationField  \
# 0  Research & Development                 8  Below College  Life Sciences
# 1  Research & Development                 2        College          Other
# 2  Research & Development                 3         Master  Life Sciences
# 3  Research & Development                 2        College  Life Sciences
# 4  Research & Development                24  Below College  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                 Very High            80
# 1              1  ...                    Medium            80
# 2              1  ...                      High            80
# 3              1  ...                      High            80
# 4              1  ...                    Medium            80
#
#   StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                1                 10                     3           Better
# 1                0                  7                     3           Better
# 2                0                  8                     3           Better
# 3                0                  8                     2             Good
# 4                1                  1                     2           Better
#
#   YearsAtCompany YearsInCurrentRole YearsSinceLastPromotion  \
# 0             10                  7                       1
# 1              0                  0                       0
# 2              8                  7                       3
# 3              7                  7                       3
# 4              1                  0                       0
#
#    YearsWithCurrManager
# 0                     7
# 1                     0
# 2                     0
# 3                     6
# 4                     0
#
# [5 rows x 36 columns]

# %%
# Replace the numbers with it's meaning
df['Education'] = df['Education'].replace([1,2,3,4,5],['Below College','College','Bachelor','Master','Doctor'])
df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['JobInvolvement'] = df['JobInvolvement'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['JobSatisfaction'] = df['JobSatisfaction'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['PerformanceRating'] = df['PerformanceRating'].replace([1,2,3,4],['Low','Good','Excellent','Outstanding'])
df['RelationshipSatisfaction'] = df['RelationshipSatisfaction'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['WorkLifeBalance'] = df['WorkLifeBalance'].replace([1,2,3,4],['Bad','Good','Better','Best'])
df['Attrition'] = df['Attrition'].replace(['No','Yes'],[0,1])
df.to_csv('HR-Employee-Attrition.csv')
df.head()
# Out:
#    Unnamed: 0  Age  Attrition     BusinessTravel  DailyRate  \
# 0           1   49          0  Travel_Frequently        279
# 1           2   37          1      Travel_Rarely       1373
# 2           3   33          0  Travel_Frequently       1392
# 3           5   32          0  Travel_Frequently       1005
# 4           7   30          0      Travel_Rarely       1358
#
#                Department  DistanceFromHome      Education EducationField  \
# 0  Research & Development                 8  Below College  Life Sciences
# 1  Research & Development                 2        College          Other
# 2  Research & Development                 3         Master  Life Sciences
# 3  Research & Development                 2        College  Life Sciences
# 4  Research & Development                24  Below College  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                 Very High            80
# 1              1  ...                    Medium            80
# 2              1  ...                      High            80
# 3              1  ...                      High            80
# 4              1  ...                    Medium            80
#
#   StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                1                 10                     3           Better
# 1                0                  7                     3           Better
# 2                0                  8                     3           Better
# 3                0                  8                     2             Good
# 4                1                  1                     2           Better
#
#   YearsAtCompany YearsInCurrentRole YearsSinceLastPromotion  \
# 0             10                  7                       1
# 1              0                  0                       0
# 2              8                  7                       3
# 3              7                  7                       3
# 4              1                  0                       0
#
#    YearsWithCurrManager
# 0                     7
# 1                     0
# 2                     0
# 3                     6
# 4                     0
#
# [5 rows x 36 columns]

# %%
Attrition_Gender=df.groupby(['Attrition','Gender'])[['EmployeeCount']].sum()
print(Attrition_Gender)
gender=df.groupby(['Gender'])[['EmployeeCount']].sum()
print(gender)
education=df.groupby(['Education'])[['EmployeeCount']].sum()
print(education)
MaritalStatus=df.groupby(['MaritalStatus'])[['EmployeeCount']].sum()
print(MaritalStatus)
Department=df.groupby(['Department'])[['EmployeeCount']].sum()
print(Department)
PerformanceRating=df.groupby(['PerformanceRating'])[['EmployeeCount']].sum()
print(PerformanceRating)
BusinessTravel=df.groupby(['BusinessTravel'])[['EmployeeCount']].sum()
print(BusinessTravel)
EnvironmentSatisfaction=df.groupby(['EnvironmentSatisfaction'])[['EmployeeCount']].sum()
print(EnvironmentSatisfaction)
# Out:
#                   EmployeeCount
# Attrition Gender
# 0         Female            285
#           Male              453
# 1         Female             59
#           Male              105
#         EmployeeCount
# Gender
# Female            344
# Male              558
#                EmployeeCount
# Education
# Bachelor                 347
# Below College            107
# College                  177
# Doctor                    26
# Master                   245
#                EmployeeCount
# MaritalStatus
# Divorced                 170
# Married                  413
# Single                   319
#                         EmployeeCount
# Department
# Human Resources                    38
# Research & Development            573
# Sales                             291
#                    EmployeeCount
# PerformanceRating
# Excellent                    761
# Outstanding                  141
#                    EmployeeCount
# BusinessTravel
# Non-Travel                    87
# Travel_Frequently            178
# Travel_Rarely                637
#                          EmployeeCount
# EnvironmentSatisfaction
# High                               279
# Low                                163
# Medium                             184
# Very High                          276

# %%
plt.hist(df['Age'])
# Out:
# (array([ 42.,  82., 152., 196., 187., 108.,  60.,  32.,  24.,  19.]),
#  array([18. , 22.2, 26.4, 30.6, 34.8, 39. , 43.2, 47.4, 51.6, 55.8, 60. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df['Education'], df['Attrition'], color ='maroon',
        width = 0.4)
 
plt.xlabel("Education")
plt.ylabel("Attrition")
plt.title("Attrition by Age ")
plt.show()
