# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
plt.style.use('ggplot')
df=pd.read_csv('HR-Employee-Attrition.csv')

# %%
df.shape
# Out:
# (971, 36)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# rows * columns
df.size
# Out:
# 34956

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Attrition     BusinessTravel  DailyRate  \
# 0           1   49          0  Travel_Frequently        279
# 1           2   37          1      Travel_Rarely       1373
# 2           3   33          0  Travel_Frequently       1392
# 3           5   32          0  Travel_Frequently       1005
# 4           7   30          0      Travel_Rarely       1358
#
#                Department  DistanceFromHome      Education EducationField  \
# 0  Research & Development                 8  Below College  Life Sciences
# 1  Research & Development                 2        College          Other
# 2  Research & Development                 3         Master  Life Sciences
# 3  Research & Development                 2        College  Life Sciences
# 4  Research & Development                24  Below College  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                 Very High            80
# 1              1  ...                    Medium            80
# 2              1  ...                      High            80
# 3              1  ...                      High            80
# 4              1  ...                    Medium            80
#
#   StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                1                 10                     3           Better
# 1                0                  7                     3           Better
# 2                0                  8                     3           Better
# 3                0                  8                     2             Good
# 4                1                  1                     2           Better
#
#   YearsAtCompany YearsInCurrentRole YearsSinceLastPromotion  \
# 0             10                  7                       1
# 1              0                  0                       0
# 2              8                  7                       3
# 3              7                  7                       3
# 4              1                  0                       0
#
#    YearsWithCurrManager
# 0                     7
# 1                     0
# 2                     0
# 3                     6
# 4                     0
#
# [5 rows x 36 columns]

# %%
# check the null values 
df.isnull()
# Out:
#      Unnamed: 0    Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0         False  False      False           False      False       False
# 1         False  False      False           False      False       False
# 2         False  False      False           False      False       False
# 3         False  False      False           False      False       False
# 4         False  False      False           False      False       False
# ..          ...    ...        ...             ...        ...         ...
# 966       False  False      False           False      False       False
# 967       False  False      False           False      False       False
# 968       False  False      False           False      False       False
# 969       False  False      False           False      False       False
# 970       False  False      False           False      False       False
#
#      DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0               False      False           False          False  ...
# 1               False      False           False          False  ...
# 2               False      False           False          False  ...
# 3               False      False           False          False  ...
# 4               False      False           False          False  ...
# ..                ...        ...             ...            ...  ...
# 966             False      False           False          False  ...
# 967             False      False           False          False  ...
# 968             False      False           False          False  ...
# 969             False      False           False          False  ...
# 970             False      False           False          False  ...
#
#      RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                       False          False             False
# 1                       False          False             False
# 2                       False          False             False
# 3                       False          False             False
# 4                       False          False             False
# ..                        ...            ...               ...
# 966                     False          False             False
# 967                     False          False             False
# 968                     False          False             False
# 969                     False          False             False
# 970                     False          False             False
#
#      TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                False                  False            False
# 1                False                  False            False
# 2                False                  False            False
# 3                False                  False            False
# 4                False                  False            False
# ..                 ...                    ...              ...
# 966              False                  False            False
# 967              False                  False            False
# 968              False                  False            False
# 969              False                  False            False
# 970              False                  False            False
#
#      YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0             False               False                    False
# 1             False               False                    False
# 2             False               False                    False
# 3             False               False                    False
# 4             False               False                    False
# ..              ...                 ...                      ...
# 966           False               False                    False
# 967           False               False                    False
# 968           False               False                    False
# 969           False               False                    False
# 970           False               False                    False
#
#      YearsWithCurrManager
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ..                    ...
# 966                 False
# 967                 False
# 968                 False
# 969                 False
# 970                 False
#
# [971 rows x 36 columns]

# %%
# check the null values 
np.sum(df.isnull())
# Out:
# Unnamed: 0                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# check if there is empty data
df.empty
# Out:
# False

# %%
# check for duplicate data
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# Length: 971, dtype: bool

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Attrition     BusinessTravel  DailyRate  \
# 0           1   49          0  Travel_Frequently        279
# 1           2   37          1      Travel_Rarely       1373
# 2           3   33          0  Travel_Frequently       1392
# 3           5   32          0  Travel_Frequently       1005
# 4           7   30          0      Travel_Rarely       1358
#
#                Department  DistanceFromHome      Education EducationField  \
# 0  Research & Development                 8  Below College  Life Sciences
# 1  Research & Development                 2        College          Other
# 2  Research & Development                 3         Master  Life Sciences
# 3  Research & Development                 2        College  Life Sciences
# 4  Research & Development                24  Below College  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                 Very High            80
# 1              1  ...                    Medium            80
# 2              1  ...                      High            80
# 3              1  ...                      High            80
# 4              1  ...                    Medium            80
#
#   StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                1                 10                     3           Better
# 1                0                  7                     3           Better
# 2                0                  8                     3           Better
# 3                0                  8                     2             Good
# 4                1                  1                     2           Better
#
#   YearsAtCompany YearsInCurrentRole YearsSinceLastPromotion  \
# 0             10                  7                       1
# 1              0                  0                       0
# 2              8                  7                       3
# 3              7                  7                       3
# 4              1                  0                       0
#
#    YearsWithCurrManager
# 0                     7
# 1                     0
# 2                     0
# 3                     6
# 4                     0
#
# [5 rows x 36 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0         Age   Attrition    DailyRate  DistanceFromHome  \
# count   971.000000  971.000000  971.000000   971.000000        971.000000
# mean    737.178167   35.435633    0.175077   796.744593          9.441813
# std     429.465664    8.386214    0.380229   400.245570          8.230160
# min       1.000000   18.000000    0.000000   103.000000          1.000000
# 25%     363.500000   30.000000    0.000000   465.000000          2.000000
# 50%     721.000000   35.000000    0.000000   793.000000          7.000000
# 75%    1112.500000   40.000000    0.000000  1148.500000         15.000000
# max    1469.000000   60.000000    1.000000  1498.000000         29.000000
#
#        EmployeeCount  EmployeeNumber  HourlyRate    JobLevel  MonthlyIncome  \
# count          971.0      971.000000  971.000000  971.000000     971.000000
# mean             1.0     1028.665294   65.739444    1.777549    5194.464470
# std              0.0      609.067611   20.414496    0.778546    3017.365749
# min              1.0        2.000000   30.000000    1.000000    1051.000000
# 25%              1.0      485.500000   48.000000    1.000000    2792.000000
# 50%              1.0     1005.000000   66.000000    2.000000    4478.000000
# 75%              1.0     1573.500000   83.000000    2.000000    6443.000000
# max              1.0     2068.000000  100.000000    4.000000   16437.000000
#
#        ...  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# count  ...          971.000000         971.000000          971.0
# mean   ...            2.385170          15.329557           80.0
# std    ...            2.203546           3.678937            0.0
# min    ...            0.000000          11.000000           80.0
# 25%    ...            1.000000          12.000000           80.0
# 50%    ...            1.000000          14.000000           80.0
# 75%    ...            4.000000          18.000000           80.0
# max    ...            8.000000          25.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count        971.000000         971.000000             971.000000
# mean           0.663234           9.235839               2.522142
# std            0.687801           5.203388               0.750446
# min            0.000000           0.000000               1.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000           9.000000               2.000000
# 75%            1.000000          12.000000               3.000000
# max            2.000000          23.000000               4.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count      971.000000          971.000000               971.000000
# mean         6.050463            3.911432                 1.834192
# std          4.456494            3.304228                 2.677956
# min          0.000000            0.000000                 0.000000
# 25%          3.000000            2.000000                 0.000000
# 50%          5.000000            3.000000                 1.000000
# 75%          9.000000            7.000000                 2.000000
# max         22.000000           16.000000                15.000000
#
#        YearsWithCurrManager
# count            971.000000
# mean               3.832132
# std                3.221647
# min                0.000000
# 25%                2.000000
# 50%                3.000000
# 75%                7.000000
# max               14.000000
#
# [8 rows x 21 columns]

# %%
check_outlier=df[['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked','Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
      'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
ax = sns.boxplot(data=check_outlier, orient="h", palette="Set1")

# %%
check_outlier1=df[['Age', 'DailyRate','DistanceFromHome', 'HourlyRate', 'JobLevel',
                   'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked']]

check_outlier2=df[['PercentSalaryHike', 'StandardHours', 'StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsWithCurrManager']]

# %%
ax = sns.boxplot(data=check_outlier1, orient="h", palette="Set2")

# %%
ax = sns.boxplot(data=check_outlier2, orient="h", palette="Set2")

# %%
#sns.boxplot(x='Age', data=df) 
#sns.boxplot(x='DistanceFromHome', data=df)
#sns.boxplot(x='HourlyRate', data=df)
#sns.boxplot(x='JobLevel', data=df)
#sns.boxplot(x='MonthlyRate', data=df)
#sns.boxplot(x='PercentSalaryHike', data=df)
#sns.boxplot(x='StandardHours', data=df)
#==========================================
#Outliers
#sns.boxplot(x='MonthlyIncome', data=df)
#sns.boxplot(x='StockOptionLevel', data=df)
#sns.boxplot(x='TotalWorkingYears', data=df)
#sns.boxplot(x='TrainingTimesLastYear', data=df)
#sns.boxplot(x='YearsWithCurrManager', data=df)
#sns.boxplot(x='NumCompaniesWorked', data=df)
#==========================================
Outliers_Detected=df[['MonthlyIncome','StockOptionLevel', 'TotalWorkingYears', 
                    'TrainingTimesLastYear','YearsWithCurrManager','NumCompaniesWorked']]
ax = sns.boxplot(data=Outliers_Detected, orient="h", palette="Set2")

# %%
#Q1 The 1st quartile/25th percentile of the data.
#Q2 The 2nd quartile/median/50th percentile of the data.
#Q3 The 3rd quartile/75th percentile of the data.
out=[]
def iqr_outliers(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    for i in df:
        if i > Upper_tail or i < Lower_tail:
            out.append(i)
    print("Outliers:",out)
iqr_outliers(df['NumCompaniesWorked'])
iqr_outliers(df['MonthlyIncome'])
iqr_outliers(df['StockOptionLevel'])
iqr_outliers(df['TotalWorkingYears'])
iqr_outliers(df['TrainingTimesLastYear'])
iqr_outliers(df['YearsWithCurrManager'])
# Out:
# Outliers: []
# Outliers: [11994, 13458, 13245, 13664, 13503, 13591, 16064, 13496, 13603, 13525, 16015, 12061, 15992, 12504, 11935, 13610, 13237, 16184, 15402, 12808, 13582, 14852, 13194, 13973, 12742, 13320, 13120, 13758, 16124, 16422, 16437, 15202, 15379, 13116, 13464, 15787, 13341, 11957, 13206, 13744, 13570, 12031]
# Outliers: [11994, 13458, 13245, 13664, 13503, 13591, 16064, 13496, 13603, 13525, 16015, 12061, 15992, 12504, 11935, 13610, 13237, 16184, 15402, 12808, 13582, 14852, 13194, 13973, 12742, 13320, 13120, 13758, 16124, 16422, 16437, 15202, 15379, 13116, 13464, 15787, 13341, 11957, 13206, 13744, 13570, 12031]
# Outliers: [11994, 13458, 13245, 13664, 13503, 13591, 16064, 13496, 13603, 13525, 16015, 12061, 15992, 12504, 11935, 13610, 13237, 16184, 15402, 12808, 13582, 14852, 13194, 13973, 12742, 13320, 13120, 13758, 16124, 16422, 16437, 15202, 15379, 13116, 13464, 15787, 13341, 11957, 13206, 13744, 13570, 12031, 22, 23, 23, 22, 23, 22, 22, 22, 22, 22, 22, 23, 23, 22, 22, 23, 23, 23, 23]
# Outliers: [11994, 13458, 13245, 13664, 13503, 13591, 16064, 13496, 13603, 13525, 16015, 12061, 15992, 12504, 11935, 13610, 13237, 16184, 15402, 12808, 13582, 14852, 13194, 13973, 12742, 13320, 13120, 13758, 16124, 16422, 16437, 15202, 15379, 13116, 13464, 15787, 13341, 11957, 13206, 13744, 13570, 12031, 22, 23, 23, 22, 23, 22, 22, 22, 22, 22, 22, 23, 23, 22, 22, 23, 23, 23, 23]
# Outliers: [11994, 13458, 13245, 13664, 13503, 13591, 16064, 13496, 13603, 13525, 16015, 12061, 15992, 12504, 11935, 13610, 13237, 16184, 15402, 12808, 13582, 14852, 13194, 13973, 12742, 13320, 13120, 13758, 16124, 16422, 16437, 15202, 15379, 13116, 13464, 15787, 13341, 11957, 13206, 13744, 13570, 12031, 22, 23, 23, 22, 23, 22, 22, 22, 22, 22, 22, 23, 23, 22, 22, 23, 23, 23, 23]

# %%
# Droping the ouliers using percentile
def drop_outliers(df, field_name):
    iqr = 1.5 * (np.percentile(df[field_name], 75) - np.percentile(df[field_name], 25))
    df.drop(df[df[field_name] > (iqr + np.percentile(df[field_name], 75))].index, inplace=True)
    df.drop(df[df[field_name] < (np.percentile(df[field_name], 25) - iqr)].index, inplace=True)
drop_outliers(df, 'MonthlyIncome')
drop_outliers(df, 'StockOptionLevel')
drop_outliers(df, 'TotalWorkingYears')
drop_outliers(df, 'TrainingTimesLastYear')
drop_outliers(df, 'YearsWithCurrManager')
drop_outliers(df, 'NumCompaniesWorked')

# %%
df1=df[df['MonthlyIncome']>10700]
df1
# Out:
#      Unnamed: 0  Age  Attrition     BusinessTravel  DailyRate  \
# 107         158   40          0      Travel_Rarely        630
# 166         251   39          0  Travel_Frequently        505
# 179         271   47          1         Non-Travel        666
# 208         313   33          0  Travel_Frequently        553
# 224         341   38          0      Travel_Rarely        343
# 299         458   40          0         Non-Travel       1094
# 339         510   54          0      Travel_Rarely        397
# 394         590   33          0      Travel_Rarely        213
# 417         625   45          0      Travel_Rarely        930
# 434         647   35          0      Travel_Rarely        672
# 486         723   46          0      Travel_Rarely        566
# 508         758   59          0      Travel_Rarely       1089
# 540         812   43          0  Travel_Frequently       1082
# 623         948   30          0      Travel_Rarely        634
# 644         992   39          0         Non-Travel       1485
# 786        1209   60          0      Travel_Rarely        370
# 922        1405   31          0         Non-Travel        697
# 964        1461   50          1      Travel_Rarely        410
#
#                  Department  DistanceFromHome Education    EducationField  \
# 107                   Sales                 4    Master         Marketing
# 166  Research & Development                 2    Master  Technical Degree
# 179  Research & Development                29    Master     Life Sciences
# 208  Research & Development                 5    Master     Life Sciences
# 224  Research & Development                15   College     Life Sciences
# 299                   Sales                28  Bachelor             Other
# 339         Human Resources                19    Master           Medical
# 394  Research & Development                 7  Bachelor           Medical
# 417                   Sales                 9  Bachelor         Marketing
# 434  Research & Development                25  Bachelor  Technical Degree
# 486  Research & Development                 7   College           Medical
# 508                   Sales                 1   College  Technical Degree
# 540  Research & Development                27  Bachelor     Life Sciences
# 623  Research & Development                17    Master           Medical
# 644  Research & Development                25   College     Life Sciences
# 786  Research & Development                 1    Master           Medical
# 922  Research & Development                10  Bachelor           Medical
# 964                   Sales                28  Bachelor         Marketing
#
#      EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 107              1  ...                       Low            80
# 166              1  ...                 Very High            80
# 179              1  ...                 Very High            80
# 208              1  ...                    Medium            80
# 224              1  ...                    Medium            80
# 299              1  ...                      High            80
# 339              1  ...                      High            80
# 394              1  ...                 Very High            80
# 417              1  ...                      High            80
# 434              1  ...                       Low            80
# 486              1  ...                    Medium            80
# 508              1  ...                      High            80
# 540              1  ...                      High            80
# 623              1  ...                 Very High            80
# 644              1  ...                    Medium            80
# 786              1  ...                      High            80
# 922              1  ...                      High            80
# 964              1  ...                    Medium            80
#
#     StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 107                1                 15                     2
# 166                0                 20                     1
# 179                1                 10                     2
# 208                2                 12                     2
# 224                1                 12                     3
# 299                1                 20                     2
# 339                1                 16                     1
# 394                0                 14                     3
# 417                1                 18                     2
# 434                0                 16                     2
# 486                1                 13                     3
# 508                1                 14                     1
# 540                1                 18                     1
# 623                2                  9                     2
# 644                1                 13                     2
# 786                1                 19                     2
# 922                1                 13                     2
# 964                1                 20                     3
#
#      WorkLifeBalance YearsAtCompany YearsInCurrentRole  \
# 107             Good             12                 11
# 166           Better             19                  6
# 179             Good             10                  7
# 208           Better             10                  6
# 224           Better             11                 10
# 299           Better              1                  0
# 339             Best              9                  7
# 394             Best             13                  9
# 417           Better              5                  4
# 434           Better             13                 10
# 486           Better              8                  7
# 508              Bad              6                  4
# 540           Better              8                  7
# 623           Better              9                  1
# 644           Better              6                  4
# 786             Best              1                  0
# 922             Best             11                  7
# 964           Better              3                  2
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 107                       2                    11
# 166                      11                     8
# 179                       9                     9
# 208                       8                     8
# 224                       2                     9
# 299                       0                     1
# 339                       7                     1
# 394                       3                     7
# 417                       0                     2
# 434                       4                     8
# 486                       0                     7
# 508                       0                     4
# 540                       0                     1
# 623                       0                     8
# 644                       0                     5
# 786                       0                     0
# 922                       4                     8
# 964                       2                     0
#
# [18 rows x 36 columns]

# %%
sns.boxplot(x='MonthlyIncome', data=df1)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
df['MonthlyIncome'].describe()
# Out:
# count      922.000000
# mean      4764.793926
# std       2387.469314
# min       1051.000000
# 25%       2743.000000
# 50%       4338.500000
# 75%       6031.250000
# max      11916.000000
# Name: MonthlyIncome, dtype: float64

# %%
df.shape
# Out:
# (922, 36)

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Attrition     BusinessTravel  DailyRate  \
# 0           1   49          0  Travel_Frequently        279
# 1           2   37          1      Travel_Rarely       1373
# 2           3   33          0  Travel_Frequently       1392
# 3           5   32          0  Travel_Frequently       1005
# 4           7   30          0      Travel_Rarely       1358
#
#                Department  DistanceFromHome      Education EducationField  \
# 0  Research & Development                 8  Below College  Life Sciences
# 1  Research & Development                 2        College          Other
# 2  Research & Development                 3         Master  Life Sciences
# 3  Research & Development                 2        College  Life Sciences
# 4  Research & Development                24  Below College  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                 Very High            80
# 1              1  ...                    Medium            80
# 2              1  ...                      High            80
# 3              1  ...                      High            80
# 4              1  ...                    Medium            80
#
#   StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                1                 10                     3           Better
# 1                0                  7                     3           Better
# 2                0                  8                     3           Better
# 3                0                  8                     2             Good
# 4                1                  1                     2           Better
#
#   YearsAtCompany YearsInCurrentRole YearsSinceLastPromotion  \
# 0             10                  7                       1
# 1              0                  0                       0
# 2              8                  7                       3
# 3              7                  7                       3
# 4              1                  0                       0
#
#    YearsWithCurrManager
# 0                     7
# 1                     0
# 2                     0
# 3                     6
# 4                     0
#
# [5 rows x 36 columns]

# %%
# Replace the numbers with it's meaning
df['Education'] = df['Education'].replace([1,2,3,4,5],['Below College','College','Bachelor','Master','Doctor'])
df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['JobInvolvement'] = df['JobInvolvement'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['JobSatisfaction'] = df['JobSatisfaction'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['PerformanceRating'] = df['PerformanceRating'].replace([1,2,3,4],['Low','Good','Excellent','Outstanding'])
df['RelationshipSatisfaction'] = df['RelationshipSatisfaction'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['WorkLifeBalance'] = df['WorkLifeBalance'].replace([1,2,3,4],['Bad','Good','Better','Best'])
df['Attrition'] = df['Attrition'].replace(['No','Yes'],[0,1])
df.to_csv('HR-Employee-Attrition.csv')
df.head()
# Out:
#    Unnamed: 0  Age  Attrition     BusinessTravel  DailyRate  \
# 0           1   49          0  Travel_Frequently        279
# 1           2   37          1      Travel_Rarely       1373
# 2           3   33          0  Travel_Frequently       1392
# 3           5   32          0  Travel_Frequently       1005
# 4           7   30          0      Travel_Rarely       1358
#
#                Department  DistanceFromHome      Education EducationField  \
# 0  Research & Development                 8  Below College  Life Sciences
# 1  Research & Development                 2        College          Other
# 2  Research & Development                 3         Master  Life Sciences
# 3  Research & Development                 2        College  Life Sciences
# 4  Research & Development                24  Below College  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                 Very High            80
# 1              1  ...                    Medium            80
# 2              1  ...                      High            80
# 3              1  ...                      High            80
# 4              1  ...                    Medium            80
#
#   StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                1                 10                     3           Better
# 1                0                  7                     3           Better
# 2                0                  8                     3           Better
# 3                0                  8                     2             Good
# 4                1                  1                     2           Better
#
#   YearsAtCompany YearsInCurrentRole YearsSinceLastPromotion  \
# 0             10                  7                       1
# 1              0                  0                       0
# 2              8                  7                       3
# 3              7                  7                       3
# 4              1                  0                       0
#
#    YearsWithCurrManager
# 0                     7
# 1                     0
# 2                     0
# 3                     6
# 4                     0
#
# [5 rows x 36 columns]

# %%
Attrition_Gender=df.groupby(['Attrition','Gender'])[['EmployeeCount']].sum()
print(Attrition_Gender)
education=df.groupby(['Education'])[['EmployeeCount']].sum()
print(education)
MaritalStatus=df.groupby(['MaritalStatus'])[['EmployeeCount']].sum()
print(MaritalStatus)
Department=df.groupby(['Department'])[['EmployeeCount']].sum()
print(Department)
PerformanceRating=df.groupby(['PerformanceRating'])[['EmployeeCount']].sum()
print(PerformanceRating)
BusinessTravel=df.groupby(['BusinessTravel'])[['EmployeeCount']].sum()
print(BusinessTravel)
EnvironmentSatisfaction=df.groupby(['EnvironmentSatisfaction'])[['EmployeeCount']].sum()
print(EnvironmentSatisfaction)
Attrition_Department=df.groupby(['Attrition',])[['EmployeeCount']].sum()
print(Department)
# Out:
#                   EmployeeCount
# Attrition Gender
# 0         Female            291
#           Male              464
# 1         Female             59
#           Male              108
#                EmployeeCount
# Education
# Bachelor                 354
# Below College            107
# College                  181
# Doctor                    26
# Master                   254
#                EmployeeCount
# MaritalStatus
# Divorced                 176
# Married                  425
# Single                   321
#                         EmployeeCount
# Department
# Human Resources                    39
# Research & Development            586
# Sales                             297
#                    EmployeeCount
# PerformanceRating
# Excellent                    776
# Outstanding                  146
#                    EmployeeCount
# BusinessTravel
# Non-Travel                    91
# Travel_Frequently            182
# Travel_Rarely                649
#                          EmployeeCount
# EnvironmentSatisfaction
# High                               290
# Low                                165
# Medium                             186
# Very High                          281
#                         EmployeeCount
# Department
# Human Resources                    39
# Research & Development            586
# Sales                             297

# %%
df.groupby('Age')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# Age
# 19    0.625000
# 18    0.500000
# 20    0.500000
# 21    0.500000
# 50    0.500000
# 26    0.321429
# 28    0.314286
# 23    0.307692
# 24    0.300000
# 31    0.294118
# 56    0.285714
# 29    0.282609
# 58    0.250000
# 22    0.250000
# 33    0.225000
# 44    0.214286
# 32    0.208333
# 49    0.200000
# 39    0.190476
# 25    0.190476
# 47    0.166667
# 55    0.166667
# 53    0.166667
# 51    0.166667
# 46    0.153846
# 52    0.142857
# 35    0.135593
# 37    0.131579
# 48    0.125000
# 34    0.116667
# 30    0.116279
# 27    0.103448
# 41    0.095238
# 40    0.090909
# 43    0.066667
# 36    0.060000
# 38    0.047619
# 42    0.043478
# 45    0.041667
# 54    0.000000
# 57    0.000000
# 59    0.000000
# 60    0.000000
# Name: Attrition, dtype: float64

# %%
exp_val=[ 0.625000,0.500000,0.500000,0.500000,0.500000,0.321429,0.321429,0.307692, 0.300000,0.294118]
exp_label=['19','18','20','21','50','26','28','23','24','31']

plt.pie(exp_val,labels=exp_label,radius=1.5,autopct='%0.2f%%');

# %%
sns.catplot(x='Age',hue='Attrition',kind='count',data=df)

# %%
#Plot Age histogram
plt.xlabel('Age')
plt.ylabel('EmployeeCount')
plt.title('Histogram of Age', fontsize = 20)
plt.hist(df['Age'])
# Out:
# (array([ 42.,  82., 156., 204., 195., 131.,  68.,  42.,  29.,  22.]),
#  array([18. , 22.2, 26.4, 30.6, 34.8, 39. , 43.2, 47.4, 51.6, 55.8, 60. ]),
#  <BarContainer object of 10 artists>)

# %%
Education_Attrition=df.groupby('Education')['Attrition'].agg(np.mean).sort_values(ascending=False)
Education_Attrition
# Out:
# Education
# Below College    0.189655
# Bachelor         0.183288
# College          0.176471
# Master           0.164794
# Doctor           0.100000
# Name: Attrition, dtype: float64

# %%
sns.catplot(x='Education',hue='Attrition',kind='count',data=df)

# %%
df.groupby('Department')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# Department
# Sales                     0.208333
# Human Resources           0.175000
# Research & Development    0.158320
# Name: Attrition, dtype: float64

# %%
exp_val=[0.208333,0.175000,0.158320]
exp_label=['Sales','Human Resources','Research & Development']

plt.pie(exp_val,labels=exp_label,radius=1.5,autopct='%0.2f%%');

# %%
df.groupby('BusinessTravel')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# BusinessTravel
# Travel_Frequently    0.267016
# Travel_Rarely        0.160584
# Non-Travel           0.094737
# Name: Attrition, dtype: float64

# %%
exp_val=[0.267016,0.267016,0.094737]
exp_label=['Travel_Frequently ','Travel_Rarely','Non-Travel   ']

plt.pie(exp_val,labels=exp_label,radius=1.5,autopct='%0.2f%%');

# %%
df.groupby('YearsSinceLastPromotion')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# YearsSinceLastPromotion
# 13    0.500000
# 15    0.500000
# 9     0.444444
# 7     0.250000
# 10    0.250000
# 0     0.206468
# 2     0.155340
# 3     0.151515
# 1     0.151394
# 6     0.150000
# 4     0.085714
# 11    0.083333
# 5     0.033333
# 8     0.000000
# 12    0.000000
# 14    0.000000
# Name: Attrition, dtype: float64

# %%
sns.catplot(x='YearsSinceLastPromotion',hue='Attrition',kind='count',data=df)
