# %% [markdown]
# # Data set created by IBM data scientists, it has around 1470 employees. Every year around (15%-20%) of them need to be replaced.(Employees leaving, or because they got fired) which is bad for the company:
#  1- Projects get delayed, resulting in a reputation loss among consumers and partners.
#
# 2- The new employees have to be trained for the job.
# The managment of the company need to identify the factors which cause employee attrition.Also,they need to understand what changes they should make to their workplace, in order to get most of their employees to stay.

# %% [markdown]
# # Checklists :
# - Inspecting.
# - Cleansing (Missing values,Empty data,Incorrect Type,Incorrect values,Outliers and non relevant data)
# - Transforming (Reshaping,Transforming Structures,Indexing for quick access,Merging and Joining)
# - Modeling with the goal of discovering usful information (Visualization,Statical models,Correlation,Reporting)
# - Informing conclusion and supporting decision-making

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
plt.style.use('ggplot')
df=pd.read_csv('HR-Employee-Attrition.csv')

# %%
# Number of rows and columns (1470,35)
df.shape
# Out:
# (846, 38)

# %%
# 35 columns
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# rows * columns
df.size
# Out:
# 51450

# %%
# show 5 rows
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# check the null values 
df.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
# check the null values 
np.sum(df.isnull())
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# check if there is empty data
df.empty
# Out:
# False

# %%
# check for duplicate data
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
# show 5 rows
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# save the columns in check_outlierdf 
check_outlier=df[['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked','Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
      'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
# Check the outliers using boxplot
ax = sns.boxplot(data=check_outlier, orient="h", palette="Set1")

# %%
# split the check_outlier into check_outlier1 and check_outlier2 to see more clearly
check_outlier1=df[['Age', 'DailyRate','DistanceFromHome', 'HourlyRate', 'JobLevel',
                   'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked']]

check_outlier2=df[['PercentSalaryHike', 'StandardHours', 'StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsWithCurrManager']]

# %%
# use boxplot to check outliers in check_outlier1 df
ax = sns.boxplot(data=check_outlier1, orient="h", palette="Set2")

# %%
# use boxplot to check outliers in check_outlier2 df
ax = sns.boxplot(data=check_outlier2, orient="h", palette="Set2")

# %%
# check the columns one by one in detect the outliers and save them in Outliers_Detected df
#sns.boxplot(x='Age', data=df) 
#sns.boxplot(x='DistanceFromHome', data=df)
#sns.boxplot(x='HourlyRate', data=df)
#sns.boxplot(x='JobLevel', data=df)
#sns.boxplot(x='MonthlyRate', data=df)
#sns.boxplot(x='PercentSalaryHike', data=df)
#sns.boxplot(x='StandardHours', data=df)
#==========================================
#Outliers
#sns.boxplot(x='MonthlyIncome', data=df)
#sns.boxplot(x='StockOptionLevel', data=df)
#sns.boxplot(x='TotalWorkingYears', data=df)
#sns.boxplot(x='TrainingTimesLastYear', data=df)
#sns.boxplot(x='YearsWithCurrManager', data=df)
#sns.boxplot(x='NumCompaniesWorked', data=df)
#==========================================
Outliers_Detected=df[['MonthlyIncome','StockOptionLevel', 'TotalWorkingYears', 
                    'TrainingTimesLastYear','YearsWithCurrManager','NumCompaniesWorked']]
ax = sns.boxplot(data=Outliers_Detected, orient="h", palette="Set2")

# %%
# use the quantile to detect the outliers (double check)
#Q1 The 1st quartile/25th percentile of the data.
#Q2 The 2nd quartile/median/50th percentile of the data.
#Q3 The 3rd quartile/75th percentile of the data.
out=[]
def iqr_outliers(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    for i in df:
        if i > Upper_tail or i < Lower_tail:
            out.append(i)
    print("Outliers:",out)
iqr_outliers(df['NumCompaniesWorked'])
iqr_outliers(df['MonthlyIncome'])
iqr_outliers(df['StockOptionLevel'])
iqr_outliers(df['TotalWorkingYears'])
iqr_outliers(df['TrainingTimesLastYear'])
iqr_outliers(df['YearsWithCurrManager'])
# Out:
# Outliers: []
# Outliers: []
# Outliers: []
# Outliers: []
# Outliers: []
# Outliers: []

# %%
# Droping the ouliers using percentile
def drop_outliers(df, field_name):
    iqr = 1.5 * (np.percentile(df[field_name], 75) - np.percentile(df[field_name], 25))
    df.drop(df[df[field_name] > (iqr + np.percentile(df[field_name], 75))].index, inplace=True)
    df.drop(df[df[field_name] < (np.percentile(df[field_name], 25) - iqr)].index, inplace=True)
drop_outliers(df, 'MonthlyIncome')
drop_outliers(df, 'StockOptionLevel')
drop_outliers(df, 'TotalWorkingYears')
drop_outliers(df, 'TrainingTimesLastYear')
drop_outliers(df, 'YearsWithCurrManager')
drop_outliers(df, 'NumCompaniesWorked')

# %%
# check the outliers again for all Outliers_Detected df and i found MonthlyIncome & TotalWorkingYears still has 
# an outliers so, I decide to delete them manualy 
Outliers_MonthlyIncome=df[['MonthlyIncome']]
ax = sns.boxplot(data=Outliers_MonthlyIncome, orient="h", palette="Set2")

# %%
# check the outliers again for all Outliers_Detected df and i found MonthlyIncome & TotalWorkingYears still has 
# an outliers so, I decide to delete them manualy 
Outliers_TotalWorkingYears=df[['TotalWorkingYears']]
ax = sns.boxplot(data=Outliers_TotalWorkingYears, orient="h", palette="Set2")

# %%
# Delete MonthlyIncome outliers manualy 
df=df[df['MonthlyIncome']<10000]

# %%
# Delete TotalWorkingYears outliers manualy 
df=df[df['TotalWorkingYears']<18]

# %%
df['MonthlyIncome'].describe()
# Out:
# count     846.000000
# mean     4518.436170
# std      2131.895855
# min      1051.000000
# 25%      2700.750000
# 50%      4231.500000
# 75%      5743.750000
# max      9998.000000
# Name: MonthlyIncome, dtype: float64

# %%
df.shape
# Out:
# (846, 35)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 5                 2          2  Life Sciences              1               8
# 7                24          1  Life Sciences              1              11
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Replace the numbers with it's meaning
df['Education'] = df['Education'].replace([1,2,3,4,5],['Below College','College','Bachelor','Master','Doctor'])
df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['JobInvolvement'] = df['JobInvolvement'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['JobSatisfaction'] = df['JobSatisfaction'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['PerformanceRating'] = df['PerformanceRating'].replace([1,2,3,4],['Low','Good','Excellent','Outstanding'])
df['RelationshipSatisfaction'] = df['RelationshipSatisfaction'].replace([1,2,3,4],['Low','Medium','High','Very High'])
df['WorkLifeBalance'] = df['WorkLifeBalance'].replace([1,2,3,4],['Bad','Good','Better','Best'])
df.to_csv('HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 5                 2        College  Life Sciences              1
# 7                24  Below College  Life Sciences              1
#
#    EmployeeNumber  ... RelationshipSatisfaction StandardHours  \
# 1               2  ...                Very High            80
# ...

# %%
Attrition_count=pd.DataFrame(df['Attrition'].value_counts())
Attrition_count
# Out:
#      Attrition
# No         689
# Yes        157

# %%
# Draw pie for the above result

sizes = [689, 157]
plt.pie(sizes,labels=['No','Yes'],radius=1.5, explode=(0.2,0),shadow=True,autopct='%1.1f%%')

plt.show()

# %%
# Attrition rate

print(len(df[df.Attrition=='Yes'])/len(df)*100)
# Out:
# 18.55791962174941

# %%
Attrition_Gender=df.groupby(['Attrition','Gender'])[['EmployeeCount']].sum()
print(Attrition_Gender)
PerformanceRating=df.groupby(['Attrition','PerformanceRating'])[['EmployeeCount']].sum()
print(PerformanceRating)

education=df.groupby(['Attrition','Education'])[['EmployeeCount']].sum()
print(education)
MaritalStatus=df.groupby(['Attrition','MaritalStatus'])[['EmployeeCount']].sum()
print(MaritalStatus)
Department=df.groupby(['Attrition','Department'])[['EmployeeCount']].sum()
print(Department)
PerformanceRating=df.groupby(['Attrition','PerformanceRating'])[['EmployeeCount']].sum()
print(PerformanceRating)
BusinessTravel=df.groupby(['Attrition','BusinessTravel'])[['EmployeeCount']].sum()
print(BusinessTravel)
OverTime=df.groupby(['Attrition','OverTime'])[['EmployeeCount']].sum()
print(OverTime)
# Out:
#                   EmployeeCount
# Attrition Gender
# 0         Female            258
#           Male              431
# 1         Female             57
#           Male              100
#                              EmployeeCount
# Attrition PerformanceRating
# 0         Excellent                    583
#           Outstanding                  106
# 1         Excellent                    132
#           Outstanding                   25
#                          EmployeeCount
# Attrition Education
# 0         Bachelor                 264
#           Below College             80
#           College                  136
#           Doctor                    22
#           Master                   187
# 1         Bachelor                  65
#           Below College             21
#           College                   30
#           Doctor                     3
#           Master                    38
#                          EmployeeCount
# Attrition MaritalStatus
# ...

# %% [markdown]
# ## Some statistics on the relationship between Attrition and some columns

# %%
#Plot Age histogram
plt.xlabel('Age')
plt.ylabel('EmployeeCount')
plt.title('Histogram of Age', fontsize = 20)
plt.hist(df['Age'])
# Out:
# (array([ 42.,  82., 152., 194., 170.,  93.,  56.,  25.,  16.,  16.]),
#  array([18. , 22.2, 26.4, 30.6, 34.8, 39. , 43.2, 47.4, 51.6, 55.8, 60. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## - The majority of employees aged 30 to 40

# %%
#separate Attrition column to two columns (yes/no)
Attrition_d=pd.get_dummies(df['Attrition'])
Attrition_d.head()
# Out:
#    No  Yes
# 1   1    0
# 2   0    1
# 3   1    0
# 5   1    0
# 7   1    0

# %%
# Concat the new two columns to the dataset
df=pd.concat([df,Attrition_d], axis=1)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 5                 2        College  Life Sciences              1
# 7                24  Below College  Life Sciences              1
#
#    EmployeeNumber  ... StockOptionLevel TotalWorkingYears  \
# 1               2  ...                1                10
# ...

# %%
#show the correlation between the columns
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot = True, fmt = '.2f')
# Out:
# <AxesSubplot:>

# %%
# replace no, yes with 0 ,1 for addtional regression analysis
df['Attrition'] = df['Attrition'].replace(['No','Yes'],[0,1])
df.to_csv('HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 5   32          0  Travel_Frequently       1005  Research & Development
# 7   30          0      Travel_Rarely       1358  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 5                 2        College  Life Sciences              1
# 7                24  Below College  Life Sciences              1
#
#    EmployeeNumber  ... StockOptionLevel TotalWorkingYears  \
# 1               2  ...                1                10
# ...

# %% [markdown]
# ## - Replace 0,1 Attrition column to 'No','Yes'

# %%
df.groupby('Age')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# Age
# 19    0.625000
# 18    0.500000
# 20    0.500000
# 21    0.500000
# 50    0.500000
# 56    0.400000
# 26    0.321429
# 28    0.314286
# 23    0.307692
# 24    0.300000
# 31    0.300000
# 29    0.282609
# 22    0.250000
# 58    0.250000
# 33    0.236842
# 39    0.235294
# 44    0.230769
# 55    0.200000
# 52    0.200000
# 32    0.195652
# 25    0.190476
# 46    0.181818
# 35    0.145455
# 40    0.120000
# 30    0.119048
# 34    0.116667
# 37    0.114286
# 49    0.111111
# 47    0.111111
# 27    0.103448
# 41    0.100000
# 43    0.083333
# 38    0.060606
# 42    0.052632
# 45    0.043478
# 36    0.042553
# 48    0.000000
# 51    0.000000
# 53    0.000000
# 54    0.000000
# 57    0.000000
# 59    0.000000
# 60    0.000000
# Name: Attrition, dtype: float64

# %% [markdown]
# ## - Aged 18 to 21 most attrited employees

# %%
# calculating the mean to show the realtion between Education and Attrition
Education_Attrition=df.groupby('Education')['Attrition'].agg(np.mean).sort_values(ascending=False)
Education_Attrition
# Out:
# Education
# Below College    0.207921
# Bachelor         0.197568
# College          0.180723
# Master           0.168889
# Doctor           0.120000
# Name: Attrition, dtype: float64

# %%
# calculating the mean to show the realtion between EducationField and Attrition
EducationField_Attrition=df.groupby('EducationField')['Attrition'].agg(np.mean).sort_values(ascending=False)
EducationField_Attrition
# Out:
# EducationField
# Technical Degree    0.287500
# Human Resources     0.250000
# Other               0.189655
# Marketing           0.186275
# Life Sciences       0.172805
# Medical             0.164557
# Name: Attrition, dtype: float64

# %%
# Using subplots to show the realtion between Attrition & Education,EducationField
cols = ['Education', 'EducationField']
fig, ax = plt.subplots(len(cols),1, figsize= (17,8), constrained_layout=True)
for i, col in enumerate(cols):
    
    sns.barplot(col,'Attrition', data = df, ax = ax[i], ci = None)
# Out:
# C:\Users\ask91\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ask91\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## - Employees having (Below College, Bachelor ) Education , more attrition
# ## - Employees having (Technical Degree, Human Resources) EducationField, more attrition

# %%
# Calculate the mean for Department and Attrition
df.groupby('Department')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# Department
# Sales                     0.209559
# Human Resources           0.189189
# Research & Development    0.173184
# Name: Attrition, dtype: float64

# %%
# Draw pie for the above result
exp_val=[0.208333,0.175000,0.158320]
exp_label=['Sales','Human Resources','Research & Development']

plt.pie(exp_val,labels=exp_label,radius=1.5,autopct='%0.2f%%');

# %% [markdown]
# ## - Employees in Sales department have the higher attrition

# %%
# using kdeplot to see the relation between Attrition and Distancefromhome
Attrition_Y = df[df['Attrition']==True]
Attrition_N = df[df['Attrition']==False]
sns.kdeplot(Attrition_Y.DistanceFromHome)
sns.kdeplot(Attrition_N.DistanceFromHome)
plt.legend(('Yes', 'No'))

# %% [markdown]
# ## - Higher proportion of attrited employees who stay far from the office (More than 10 KM)

# %%
# using kdeplot to see the relation between Attrition and MonthlyIncome
sns.kdeplot(Attrition_Y.MonthlyIncome)
sns.kdeplot(Attrition_N.MonthlyIncome)
plt.legend(('Yes', 'No'))

# %% [markdown]
# ## - Employees with low income are more to attrite from the company

# %%
# Using subplots to show the realtion between Attrition & 'JobSatisfaction', 'RelationshipSatisfaction', 'WorkLifeBalance', 'EnvironmentSatisfaction'
cols = ['JobSatisfaction', 'RelationshipSatisfaction', 'WorkLifeBalance', 'EnvironmentSatisfaction']
fig, ax = plt.subplots(len(cols),1, figsize= (10,8), constrained_layout=True)

for i, col in enumerate(cols):
    
    sns.barplot(col,'Attrition', data = df, ax = ax[i], ci = None)
# Out:
# C:\Users\ask91\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ask91\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ask91\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ## - Employees with ,Low JobSatisfaction, Low RelationshipSatisfaction, Bad WorkLifeBalance, Low EnvironmentSatisfaction have the higher attrition

# %%
# Using subplots to show the realtion between Attrition & 'JobLevel', 'JobRole','JobInvolvement'
cols = ['JobLevel', 'JobRole','JobInvolvement']
fig, ax = plt.subplots(len(cols),1, figsize= (17,8), constrained_layout=True)
for i, col in enumerate(cols):
    
    sns.barplot(col,'Attrition', data = df, ax = ax[i], ci = None)
# Out:
# C:\Users\ask91\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ask91\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ask91\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## - Employees with jobLevel 1 ,JopRole(Sales Representative), low job Involvement have higher attrition

# %%
# Using catplot to show Attrition with overtime
sns.catplot(x='OverTime',hue='Attrition',kind='count',data=df)

# %% [markdown]
# ## Employees with overtime almost has same attrition rate with employees with no overtime.

# %% [markdown]
# # Conclusion:
# ** Factors which cause employees attrition **
# - Low monthly income.
# - Long distance between employees home and the company location.
# - Sales department, probably becuase of the pressure on the employees from the managers.
# - Low JobSatisfaction, Low RelationshipSatisfaction, Bad WorkLifeBalance, Low EnvironmentSatisfaction in the company.
# - Sales Representative.
# - Low job Involvement.
# # Recommendations:
# - Increase the monthly salary.
# - Find accommodation for employees that is close to work.
# - Reducing the pressure on the sales department and give them a bonus to encourage them.
# - Changing the work environment and making it appropriate for achievement and improve the relationship between employees.
# - Increase the jop Involvement for the employees.
